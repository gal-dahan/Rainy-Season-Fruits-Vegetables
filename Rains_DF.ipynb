# %%
import json
import pandas as pd

# %%
with open('ims-results-json.json') as f:
    data  = json.load(f)

# %%
df = pd.DataFrame(data)
df.drop('rain_days_code', inplace=True, axis=1)
df.drop('rain_cmnt_code', inplace=True, axis=1)
df.drop('stn_num', inplace=True, axis=1)
df['time_obs']=df['time_obs'].str.replace("T00:00:00", "")
for i in range(1,10):
    df['time_obs']=df['time_obs'].str.replace("-0"+str(i)+"-01", "-0"+str(i))
for i in range(0,3):
    df['time_obs']=df['time_obs'].str.replace("-1"+str(i)+"-01", "-1"+str(i))
df
# Out:
#                                                stn_name time_obs  rain_code  \
# 0     REGAVIM                                       ...  2016-01          0
# 1     KEFAR HAROE                                   ...  2016-01          0
# 2     ENAT                                          ...  2016-01          0
# 3     NES ZIYYONA                                   ...  2016-01          0
# 4     NIZZAN                                        ...  2016-01          0
# ...                                                 ...      ...        ...
# 1321  PARAN                                         ...  2021-10          0
# 1322  YOTVATA                                       ...  2021-10          0
# 1323  YONATAN                                       ...  2021-10          0
# 1324  AVNE ETAN                                     ...  2021-10          0
# 1325  MEROM GOLAN PICMAN                            ...  2021-10          0
#
# ...

# %%
#df['rain_cmnt_code'].value_counts()

# %%
df[["year","month"]] = df["time_obs"].str.split("-", expand = True)
del df['time_obs']
for i in range(1,10):
    df['month']=df['month'].str.replace("0"+str(i), str(i))
df
# Out:
#                                                stn_name  rain_code  \
# 0     REGAVIM                                       ...          0
# 1     KEFAR HAROE                                   ...          0
# 2     ENAT                                          ...          0
# 3     NES ZIYYONA                                   ...          0
# 4     NIZZAN                                        ...          0
# ...                                                 ...        ...
# 1321  PARAN                                         ...          0
# 1322  YOTVATA                                       ...          0
# 1323  YONATAN                                       ...          0
# 1324  AVNE ETAN                                     ...          0
# 1325  MEROM GOLAN PICMAN                            ...          0
#
#       rain_days_num  rain_max_code  rain_max_val  rain_ttl  year month
# 0                14              0          64.1     166.3  2016     1
# ...

# %%
df['rain_code']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1321    0
# 1322    0
# 1323    0
# 1324    0
# 1325    0
# Name: rain_code, Length: 1326, dtype: int64

# %%
df.loc[df['month'] == '9']
# Out:
#                                                stn_name  rain_code  \
# 144   REGAVIM                                       ...          0
# 145   KEFAR HAROE                                   ...          0
# 146   ENAT                                          ...          0
# 147   NES ZIYYONA                                   ...          0
# 148   NIZZAN                                        ...          0
# ...                                                 ...        ...
# 1302  PARAN                                         ...          0
# 1303  YOTVATA                                       ...          0
# 1304  YONATAN                                       ...          0
# 1305  AVNE ETAN                                     ...          0
# 1306  MEROM GOLAN PICMAN                            ...          0
#
#       rain_days_num  rain_max_code  rain_max_val  rain_ttl  year month
# 144               0              0           0.0       0.0  2016     9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1326 entries, 0 to 1325
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   stn_name       1326 non-null   object
#  1   rain_code      1326 non-null   int64
#  2   rain_days_num  1326 non-null   int64
#  3   rain_max_code  1326 non-null   int64
#  4   rain_max_val   1326 non-null   float64
#  5   rain_ttl       1326 non-null   float64
#  6   year           1326 non-null   object
#  7   month          1326 non-null   object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 83.0+ KB

# %%
for i in df.columns:
    if(i == 'year'):
        df[i].astype(float)

# %%
df['month'] = df['month'].astype(int)
df['year'] = df['year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1326 entries, 0 to 1325
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   stn_name       1326 non-null   object
#  1   rain_code      1326 non-null   int64
#  2   rain_days_num  1326 non-null   int64
#  3   rain_max_code  1326 non-null   int64
#  4   rain_max_val   1326 non-null   float64
#  5   rain_ttl       1326 non-null   float64
#  6   year           1326 non-null   int32
#  7   month          1326 non-null   int32
# dtypes: float64(2), int32(2), int64(3), object(1)
# memory usage: 72.6+ KB

# %%
df.to_csv('Rains_DataFrame.csv', index=False)
