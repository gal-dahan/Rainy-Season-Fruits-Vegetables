# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt

import sklearn
from sklearn import linear_model, metrics, preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import r2_score, f1_score
#import mathplotlib

# %%
data_crawling = pd.read_csv ('data_from_crawling.csv')
print (data_crawling)
# Out:
#             Date Avocado A Avocado B Banana A Banana B Carrot A Carrot B  \
# 0     01.01.2016       NaN       NaN      NaN      NaN      NaN      NaN
# 1     02.01.2016       NaN       NaN      NaN      NaN      NaN      NaN
# 2     03.01.2016       7.6       8.1      2.9      NaN      2.7      NaN
# 3     04.01.2016       7.5      10.7      2.9      NaN      2.7      NaN
# 4     05.01.2016       8.8       9.6      2.9      NaN      2.6      NaN
# ...          ...       ...       ...      ...      ...      ...      ...
# 1867  22.12.2021         3      6.04        2     3.67      2.5        5
# 1868  23.12.2021         4      5.88      2.5     3.31      2.5        5
# 1869  24.12.2021       NaN       NaN      NaN      NaN      NaN      NaN
# 1870  25.12.2021       NaN       NaN      NaN      NaN      NaN      NaN
# 1871  26.12.2021       4.1      6.04      NaN     3.62     2.45      5.3
#
#      Cucumber A  Cucumber B Green Apple A  ... Red Cabbage A  Red Cabbage B  \
# 0           NaN         NaN           NaN  ...           NaN            NaN
# 1           NaN         NaN           NaN  ...           NaN            NaN
# 2           4.6         5.1           NaN  ...             6            6.1
# 3           4.1         4.4           NaN  ...             6            6.5
# 4           3.2         4.4           NaN  ...           5.9            6.2
# ...         ...         ...           ...  ...           ...            ...
# 1867       6.21         NaN           NaN  ...           2.5            NaN
# 1868       5.92         NaN           NaN  ...          2.28            NaN
# 1869        NaN         NaN           NaN  ...           NaN            NaN
# 1870        NaN         NaN           NaN  ...           NaN            NaN
# 1871       6.25         NaN           NaN  ...          2.23            NaN
#
#       Red Pepper A Red Pepper B  Sweet-Potato A Sweet-Potato B  Tomatoe A  \
# 0              NaN          NaN             NaN            NaN        NaN
# 1              NaN          NaN             NaN            NaN        NaN
# 2                8          8.1             2.7            NaN        9.1
# 3              8.2          8.8               2            NaN        NaN
# 4              6.6          7.9             2.4            NaN         10
# ...            ...          ...             ...            ...        ...
# 1867             3         5.86               3              5          3
# 1868           3.7         5.27            2.95              5        NaN
# 1869           NaN          NaN             NaN            NaN        NaN
# 1870           NaN          NaN             NaN            NaN        NaN
# 1871         3.50*         5.25           2.93*              5        NaN
#
#      Tomatoe B  Yellow Pepper A Yellow Pepper B
# 0          NaN              NaN             NaN
# 1          NaN              NaN             NaN
# 2         10.1              6.4             7.5
# 3          9.9              6.9             7.3
# 4         10.2              7.3             7.5
# ...        ...              ...             ...
# 1867       4.5                3            6.06
# 1868      5.06            3.38*            5.25
# 1869       NaN              NaN             NaN
# 1870       NaN              NaN             NaN
# 1871      4.77              NaN            5.09
#
# [1872 rows x 35 columns]

# %% [markdown]
# ###### We remove all the rows that have missing values

# %%
df2=data_crawling.dropna(axis=0, thresh=20).copy()
#df2=df2.str.replace('*','')
for i in df2.columns:
    if(df2[i].dtype == 'O'):
        df2[i]=df2[i].str.replace('*','')

for i in df2.columns:
    if(i == 'Date'):
        continue
    else:df2[i].astype(float)
# Out:
# C:\Users\ED9E~1\AppData\Local\Temp/ipykernel_13632/2714564876.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2[i]=df2[i].str.replace('*','')

# %% [markdown]
# df2.fillna(method='ffill')

# %%
df2
# Out:
#             Date Avocado A Avocado B Banana A Banana B Carrot A Carrot B  \
# 2     03.01.2016       7.6       8.1      2.9      NaN      2.7      NaN
# 3     04.01.2016       7.5      10.7      2.9      NaN      2.7      NaN
# 4     05.01.2016       8.8       9.6      2.9      NaN      2.6      NaN
# 5     06.01.2016       8.8      10.1      2.8      NaN      2.9      NaN
# 6     07.01.2016       9.1      10.8      2.8      NaN      2.8      NaN
# ...          ...       ...       ...      ...      ...      ...      ...
# 1865  20.12.2021         3      5.65     2.22     3.49     2.67        4
# 1866  21.12.2021      3.33      5.85        2     3.47      2.5        5
# 1867  22.12.2021         3      6.04        2     3.67      2.5        5
# 1868  23.12.2021         4      5.88      2.5     3.31      2.5        5
# 1871  26.12.2021       4.1      6.04      NaN     3.62     2.45      5.3
#
#      Cucumber A  Cucumber B Green Apple A  ... Red Cabbage A  Red Cabbage B  \
# 2           4.6         5.1           NaN  ...             6            6.1
# 3           4.1         4.4           NaN  ...             6            6.5
# 4           3.2         4.4           NaN  ...           5.9            6.2
# 5           3.5         4.0           5.3  ...           5.5            5.7
# 6           3.5         4.9           NaN  ...           5.4            5.4
# ...         ...         ...           ...  ...           ...            ...
# 1865       5.89         NaN           NaN  ...           2.1            NaN
# 1866       6.36         NaN           NaN  ...          2.46            NaN
# 1867       6.21         NaN           NaN  ...           2.5            NaN
# 1868       5.92         NaN           NaN  ...          2.28            NaN
# 1871       6.25         NaN           NaN  ...          2.23            NaN
#
#       Red Pepper A Red Pepper B  Sweet-Potato A Sweet-Potato B  Tomatoe A  \
# 2                8          8.1             2.7            NaN        9.1
# 3              8.2          8.8               2            NaN        NaN
# 4              6.6          7.9             2.4            NaN         10
# 5                7          7.6             2.1            NaN          8
# 6              4.9          7.7             2.6            NaN        7.7
# ...            ...          ...             ...            ...        ...
# 1865          3.17         5.68               3              5          3
# 1866             3         5.63            2.95              5        NaN
# 1867             3         5.86               3              5          3
# 1868           3.7         5.27            2.95              5        NaN
# 1871          3.50         5.25            2.93              5        NaN
#
#      Tomatoe B  Yellow Pepper A Yellow Pepper B
# 2         10.1              6.4             7.5
# 3          9.9              6.9             7.3
# 4         10.2              7.3             7.5
# 5          8.4                7             7.1
# 6            8                6             6.9
# ...        ...              ...             ...
# 1865       4.5                3            5.75
# 1866       4.5             3.25               6
# 1867       4.5                3            6.06
# 1868      5.06             3.38            5.25
# 1871      4.77              NaN            5.09
#
# [1127 rows x 35 columns]

# %%
df2['Avocado A'] = pd.to_numeric(df2['Avocado A'],errors = 'coerce')
for i in df2.columns:
    if(i != "Date"):
        df2[i] = pd.to_numeric(df2[i],errors = 'coerce')

# %%
df2.info()
p_df = df2.copy()
colNameArray = ['Date','Avocado A','Avocado B','Banana A','Banana B','Carrot A','Carrot B','Cucumber A','Cucumber B','Green Apple A','Green Apple B','Green Cabbage A','Green Cabbage B','Lemon A','Lemon B','Letture A','Letture B','Onion A','Onion B','Pear A','Pear B','Pomegranate A','Pomegranate B','Red Apple A','Red Apple B','Red Cabbage A','Red Cabbage B','Red Pepper A','Red Pepper B','Sweet-Potato A','Sweet-Potato B','Tomatoe A','Tomatoe B','Yellow Pepper A','Yellow Pepper B']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1127 entries, 2 to 1871
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             1127 non-null   object
#  1   Avocado A        453 non-null    float64
#  2   Avocado B        559 non-null    float64
#  3   Banana A         971 non-null    float64
#  4   Banana B         772 non-null    float64
#  5   Carrot A         1119 non-null   float64
#  6   Carrot B         717 non-null    float64
#  7   Cucumber A       1127 non-null   float64
#  8   Cucumber B       16 non-null     float64
#  9   Green Apple A    523 non-null    float64
#  10  Green Apple B    1126 non-null   float64
#  11  Green Cabbage A  1127 non-null   float64
#  12  Green Cabbage B  9 non-null      float64
#  13  Lemon A          1011 non-null   float64
#  14  Lemon B          1087 non-null   float64
#  15  Letture A        1098 non-null   float64
#  16  Letture B        0 non-null      float64
#  17  Onion A          690 non-null    float64
#  18  Onion B          0 non-null      float64
#  19  Pear A           864 non-null    float64
#  20  Pear B           1103 non-null   float64
#  21  Pomegranate A    581 non-null    float64
#  22  Pomegranate B    752 non-null    float64
#  23  Red Apple A      478 non-null    float64
#  24  Red Apple B      1092 non-null   float64
#  25  Red Cabbage A    1127 non-null   float64
#  26  Red Cabbage B    9 non-null      float64
#  27  Red Pepper A     1049 non-null   float64
#  28  Red Pepper B     1127 non-null   float64
#  29  Sweet-Potato A   606 non-null    float64
#  30  Sweet-Potato B   1051 non-null   float64
#  31  Tomatoe A        408 non-null    float64
#  32  Tomatoe B        1126 non-null   float64
#  33  Yellow Pepper A  876 non-null    float64
#  34  Yellow Pepper B  1127 non-null   float64
# dtypes: float64(34), object(1)
# memory usage: 317.0+ KB

# %%
#p_df['Banana A'].describe()
#curMean = p_df['Banana B'].mean() - p_df['Banana A'].mean()
#curMean
for i in range(1,len(p_df.columns)-1,2):
    A_col = df2[colNameArray[i]]
    B_col = df2[colNameArray[i+1]]
    if((A_col.count() > 900)):
        curMean = B_col.mean() - A_col.mean()
        curMean = round(curMean, 2)
        for j in range(0,len(p_df)-1):
            if((math.isnan(B_col.iloc[[j]]))):
                p_df[colNameArray[i+1]].iloc[[j]] = A_col.iloc[[j]] + curMean
            else:
                continue
        print(colNameArray[i])
        print(curMean)
##  and (math.isnan(A_col.iloc[[j]]))
# Out:
# D:\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# Banana A
# 0.22
# Carrot A
# 1.16
# Cucumber A
# -0.14
# Green Cabbage A
# 2.27
# Lemon A
# 1.93
# Letture A
# nan
# Red Cabbage A
# 2.61
# Red Pepper A
# 2.49

# %%
p_df1 = p_df.copy() 
for i in range(2,len(p_df.columns),2):
    A_col = df2[colNameArray[i-1]]
    B_col = df2[colNameArray[i]]
    if((B_col.count() > 900)):
        curMean = B_col.mean() - A_col.mean()
        curMean = round(curMean, 2)
        print(colNameArray[i])
        print(colNameArray[i-1])
        for j in range(0,len(p_df)-1):
            if((math.isnan(A_col.iloc[[j]]))):
                p_df1[colNameArray[i-1]].iloc[[j]] = B_col.iloc[[j]] - curMean
            else:
                continue
       # print(colNameArray[i])
       #print(curMean)
# Out:
# Green Apple B
# Green Apple A
# Lemon B
# Lemon A
# Pear B
# Pear A
# Red Apple B
# Red Apple A
# Red Pepper B
# Red Pepper A
# Sweet-Potato B
# Sweet-Potato A
# Tomatoe B
# Tomatoe A
# Yellow Pepper B
# Yellow Pepper A

# %%
p_df
# Out:
#             Date  Avocado A  Avocado B  Banana A  Banana B  Carrot A  \
# 2     03.01.2016       7.60       8.10      2.90      3.12      2.70
# 3     04.01.2016       7.50      10.70      2.90      3.12      2.70
# 4     05.01.2016       8.80       9.60      2.90      3.12      2.60
# 5     06.01.2016       8.80      10.10      2.80      3.02      2.90
# 6     07.01.2016       9.10      10.80      2.80      3.02      2.80
# ...          ...        ...        ...       ...       ...       ...
# 1865  20.12.2021       3.00       5.65      2.22      3.49      2.67
# 1866  21.12.2021       3.33       5.85      2.00      3.47      2.50
# 1867  22.12.2021       3.00       6.04      2.00      3.67      2.50
# 1868  23.12.2021       4.00       5.88      2.50      3.31      2.50
# 1871  26.12.2021       4.10       6.04       NaN      3.62      2.45
#
#       Carrot B  Cucumber A  Cucumber B  Green Apple A  ...  Red Cabbage A  \
# 2         3.86        4.60        5.10            NaN  ...           6.00
# 3         3.86        4.10        4.40            NaN  ...           6.00
# 4         3.76        3.20        4.40            NaN  ...           5.90
# 5         4.06        3.50        4.00            5.3  ...           5.50
# 6         3.96        3.50        4.90            NaN  ...           5.40
# ...        ...         ...         ...            ...  ...            ...
# 1865      4.00        5.89        5.75            NaN  ...           2.10
# 1866      5.00        6.36        6.22            NaN  ...           2.46
# 1867      5.00        6.21        6.07            NaN  ...           2.50
# 1868      5.00        5.92        5.78            NaN  ...           2.28
# 1871      5.30        6.25         NaN            NaN  ...           2.23
#
#       Red Cabbage B  Red Pepper A  Red Pepper B  Sweet-Potato A  \
# 2              6.10          8.00          8.10            2.70
# 3              6.50          8.20          8.80            2.00
# 4              6.20          6.60          7.90            2.40
# 5              5.70          7.00          7.60            2.10
# 6              5.40          4.90          7.70            2.60
# ...             ...           ...           ...             ...
# 1865           4.71          3.17          5.68            3.00
# 1866           5.07          3.00          5.63            2.95
# 1867           5.11          3.00          5.86            3.00
# 1868           4.89          3.70          5.27            2.95
# 1871            NaN          3.50          5.25            2.93
#
#       Sweet-Potato B  Tomatoe A  Tomatoe B  Yellow Pepper A  Yellow Pepper B
# 2                NaN        9.1      10.10             6.40             7.50
# 3                NaN        NaN       9.90             6.90             7.30
# 4                NaN       10.0      10.20             7.30             7.50
# 5                NaN        8.0       8.40             7.00             7.10
# 6                NaN        7.7       8.00             6.00             6.90
# ...              ...        ...        ...              ...              ...
# 1865             5.0        3.0       4.50             3.00             5.75
# 1866             5.0        NaN       4.50             3.25             6.00
# 1867             5.0        3.0       4.50             3.00             6.06
# 1868             5.0        NaN       5.06             3.38             5.25
# 1871             5.0        NaN       4.77              NaN             5.09
#
# [1127 rows x 35 columns]

# %%
p_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1127 entries, 2 to 1871
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             1127 non-null   object
#  1   Avocado A        453 non-null    float64
#  2   Avocado B        559 non-null    float64
#  3   Banana A         971 non-null    float64
#  4   Banana B         1126 non-null   float64
#  5   Carrot A         1119 non-null   float64
#  6   Carrot B         1126 non-null   float64
#  7   Cucumber A       1127 non-null   float64
#  8   Cucumber B       1126 non-null   float64
#  9   Green Apple A    1125 non-null   float64
#  10  Green Apple B    1126 non-null   float64
#  11  Green Cabbage A  1127 non-null   float64
#  12  Green Cabbage B  1126 non-null   float64
#  13  Lemon A          1127 non-null   float64
#  14  Lemon B          1127 non-null   float64
#  15  Letture A        1098 non-null   float64
#  16  Letture B        0 non-null      float64
#  17  Onion A          690 non-null    float64
#  18  Onion B          0 non-null      float64
#  19  Pear A           1108 non-null   float64
#  20  Pear B           1103 non-null   float64
#  21  Pomegranate A    581 non-null    float64
#  22  Pomegranate B    752 non-null    float64
#  23  Red Apple A      1092 non-null   float64
#  24  Red Apple B      1092 non-null   float64
#  25  Red Cabbage A    1127 non-null   float64
#  26  Red Cabbage B    1126 non-null   float64
#  27  Red Pepper A     1127 non-null   float64
#  28  Red Pepper B     1127 non-null   float64
#  29  Sweet-Potato A   1101 non-null   float64
#  30  Sweet-Potato B   1051 non-null   float64
#  31  Tomatoe A        1125 non-null   float64
#  32  Tomatoe B        1126 non-null   float64
#  33  Yellow Pepper A  1126 non-null   float64
#  34  Yellow Pepper B  1127 non-null   float64
# dtypes: float64(34), object(1)
# memory usage: 317.0+ KB

# %%
## dataframe after filling missing values and deleted empty columns  p_df2
p_df2 = p_df1.dropna(axis=1, thresh=800).copy()

# %%
p_df2
# Out:
#             Date  Banana A  Banana B  Carrot A  Carrot B  Cucumber A  \
# 2     03.01.2016      2.90      3.12      2.70      3.86        4.60
# 3     04.01.2016      2.90      3.12      2.70      3.86        4.10
# 4     05.01.2016      2.90      3.12      2.60      3.76        3.20
# 5     06.01.2016      2.80      3.02      2.90      4.06        3.50
# 6     07.01.2016      2.80      3.02      2.80      3.96        3.50
# ...          ...       ...       ...       ...       ...         ...
# 1865  20.12.2021      2.22      3.49      2.67      4.00        5.89
# 1866  21.12.2021      2.00      3.47      2.50      5.00        6.36
# 1867  22.12.2021      2.00      3.67      2.50      5.00        6.21
# 1868  23.12.2021      2.50      3.31      2.50      5.00        5.92
# 1871  26.12.2021       NaN      3.62      2.45      5.30        6.25
#
#       Cucumber B  Green Apple A  Green Apple B  Green Cabbage A  ...  \
# 2           5.10           4.27            7.0             4.70  ...
# 3           4.40           4.77            7.5             5.00  ...
# 4           4.40           4.27            7.0             5.00  ...
# 5           4.00           5.30            6.8             4.40  ...
# 6           4.90           4.57            7.3             4.40  ...
# ...          ...            ...            ...              ...  ...
# 1865        5.75           5.27            8.0             1.45  ...
# 1866        6.22           5.27            8.0             1.44  ...
# 1867        6.07           5.27            8.0             1.34  ...
# 1868        5.78           5.27            8.0             1.27  ...
# 1871         NaN            NaN            8.0             1.32  ...
#
#       Red Cabbage A  Red Cabbage B  Red Pepper A  Red Pepper B  \
# 2              6.00           6.10          8.00          8.10
# 3              6.00           6.50          8.20          8.80
# 4              5.90           6.20          6.60          7.90
# 5              5.50           5.70          7.00          7.60
# 6              5.40           5.40          4.90          7.70
# ...             ...            ...           ...           ...
# 1865           2.10           4.71          3.17          5.68
# 1866           2.46           5.07          3.00          5.63
# 1867           2.50           5.11          3.00          5.86
# 1868           2.28           4.89          3.70          5.27
# 1871           2.23            NaN          3.50          5.25
#
#       Sweet-Potato A  Sweet-Potato B  Tomatoe A  Tomatoe B  Yellow Pepper A  \
# 2               2.70             NaN       9.10      10.10             6.40
# 3               2.00             NaN       8.19       9.90             6.90
# 4               2.40             NaN      10.00      10.20             7.30
# 5               2.10             NaN       8.00       8.40             7.00
# 6               2.60             NaN       7.70       8.00             6.00
# ...              ...             ...        ...        ...              ...
# 1865            3.00             5.0       3.00       4.50             3.00
# 1866            2.95             5.0       2.79       4.50             3.25
# 1867            3.00             5.0       3.00       4.50             3.00
# 1868            2.95             5.0       3.35       5.06             3.38
# 1871            2.93             5.0        NaN       4.77              NaN
#
#       Yellow Pepper B
# 2                7.50
# 3                7.30
# 4                7.50
# 5                7.10
# 6                6.90
# ...               ...
# 1865             5.75
# 1866             6.00
# 1867             6.06
# 1868             5.25
# 1871             5.09
#
# [1127 rows x 28 columns]

# %%
p_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1127 entries, 2 to 1871
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             1127 non-null   object
#  1   Banana A         971 non-null    float64
#  2   Banana B         1126 non-null   float64
#  3   Carrot A         1119 non-null   float64
#  4   Carrot B         1126 non-null   float64
#  5   Cucumber A       1127 non-null   float64
#  6   Cucumber B       1126 non-null   float64
#  7   Green Apple A    1125 non-null   float64
#  8   Green Apple B    1126 non-null   float64
#  9   Green Cabbage A  1127 non-null   float64
#  10  Green Cabbage B  1126 non-null   float64
#  11  Lemon A          1127 non-null   float64
#  12  Lemon B          1127 non-null   float64
#  13  Letture A        1098 non-null   float64
#  14  Pear A           1108 non-null   float64
#  15  Pear B           1103 non-null   float64
#  16  Red Apple A      1092 non-null   float64
#  17  Red Apple B      1092 non-null   float64
#  18  Red Cabbage A    1127 non-null   float64
#  19  Red Cabbage B    1126 non-null   float64
#  20  Red Pepper A     1127 non-null   float64
#  21  Red Pepper B     1127 non-null   float64
#  22  Sweet-Potato A   1101 non-null   float64
#  23  Sweet-Potato B   1051 non-null   float64
#  24  Tomatoe A        1125 non-null   float64
#  25  Tomatoe B        1126 non-null   float64
#  26  Yellow Pepper A  1126 non-null   float64
#  27  Yellow Pepper B  1127 non-null   float64
# dtypes: float64(27), object(1)
# memory usage: 255.3+ KB

# %%
p_df.to_csv('data_handling_chart1.csv', index=False)

# %%
if(math.isnan(df2['Banana B'].iloc[[1126]])):
    print(True)
else:
    print(False)
# Out:
# False

# %%
print(len(p_df))
# Out:
# 1127

# %%
df_missing=p_df.copy()
df_missing[["day","month","year"]] = df_missing["Date"].str.split(".", expand = True)
df_missing
for i in range(1,12):
    df_missing['month']=df_missing['month'].apply(str).replace("0"+str(i), str(i)).astype(int)
df_missing[df_missing['Avocado A'].isnull() == True]['month']
# Out:
# 13       1
# 17       1
# 24       1
# 25       1
# 26       2
#         ..
# 1786     9
# 1789     9
# 1790     9
# 1793     9
# 1796    10
# Name: month, Length: 674, dtype: int32

# %%
#df_missing[df_missing['Avocado A'].isnull()]['month'].value_counts().plot.bar()
#plt.title("Avocado null ")
#plt.xlabel("month ")
#plt.ylabel("Avocado")

# %%
avo_A = p_df1['Avocado A']
avo_B = p_df1['Avocado B']
pmg_A = p_df1['Pomegranate A']
pmg_B = p_df1['Pomegranate B']
oni_A = p_df1['Onion A']
d_dates = p_df1['Date']
missing_val_df = pd.DataFrame({'Date':d_dates,'Avocado A':avo_A,'Avocado B':avo_B,'Pomegranate A':pmg_A,'Pomegranate B':pmg_B,
                              'Onion A':oni_A})

# %%
missing_val_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1127 entries, 2 to 1871
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1127 non-null   object
#  1   Avocado A      453 non-null    float64
#  2   Avocado B      559 non-null    float64
#  3   Pomegranate A  581 non-null    float64
#  4   Pomegranate B  752 non-null    float64
#  5   Onion A        690 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 61.6+ KB

# %%
p_missing_val_df = missing_val_df.dropna(axis=0, thresh=4).copy()

# %%
p_missing_val_df.info()
fill_p_missing_val_df = p_missing_val_df.copy()
colNameArray1 = ['Date','Avocado A','Avocado B','Pomegranate A','Pomegranate B']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 638 entries, 2 to 1871
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           638 non-null    object
#  1   Avocado A      449 non-null    float64
#  2   Avocado B      529 non-null    float64
#  3   Pomegranate A  518 non-null    float64
#  4   Pomegranate B  631 non-null    float64
#  5   Onion A        617 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 34.9+ KB

# %%
for i in range(1,len(fill_p_missing_val_df.columns)-1,2):
    A_col = p_missing_val_df[colNameArray1[i]]
    B_col = p_missing_val_df[colNameArray1[i+1]]
    if((A_col.count() > 400)):
        curMean = B_col.mean() - A_col.mean()
        curMean = round(curMean, 2)
        for j in range(0,len(fill_p_missing_val_df)-1):
            if((math.isnan(B_col.iloc[[j]]))):
                fill_p_missing_val_df[colNameArray1[i+1]].iloc[[j]] = A_col.iloc[[j]] + curMean
            else:
                continue
        print(colNameArray1[i])
        print(curMean)
# Out:
# Avocado A
# 3.27
# Pomegranate A
# 2.2
# D:\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
fill_p_missing_val_df1 = fill_p_missing_val_df.copy() 
for i in range(2,len(fill_p_missing_val_df.columns),2):
    A_col = fill_p_missing_val_df[colNameArray1[i-1]]
    B_col = fill_p_missing_val_df[colNameArray1[i]]
    if((B_col.count() > 400)):
        curMean = B_col.mean() - A_col.mean()
        curMean = round(curMean, 2)
        print(colNameArray1[i])
        print(colNameArray1[i-1])
        for j in range(0,len(fill_p_missing_val_df)-1):
            if((math.isnan(A_col.iloc[[j]]))):
                fill_p_missing_val_df1[colNameArray1[i-1]].iloc[[j]] = B_col.iloc[[j]] - curMean
            else:
                continue
# Out:
# Avocado B
# Avocado A
# Pomegranate B
# Pomegranate A

# %%
fill_p_missing_val_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 638 entries, 2 to 1871
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           638 non-null    object
#  1   Avocado A      530 non-null    float64
#  2   Avocado B      530 non-null    float64
#  3   Pomegranate A  632 non-null    float64
#  4   Pomegranate B  632 non-null    float64
#  5   Onion A        617 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 34.9+ KB

# %%
#missing_val_df.to_csv('p_missing_val_df_chart.csv', index=False)

# %%
p_df2
# Out:
#             Date  Banana A  Banana B  Carrot A  Carrot B  Cucumber A  \
# 2     03.01.2016      2.90      3.12      2.70      3.86        4.60
# 3     04.01.2016      2.90      3.12      2.70      3.86        4.10
# 4     05.01.2016      2.90      3.12      2.60      3.76        3.20
# 5     06.01.2016      2.80      3.02      2.90      4.06        3.50
# 6     07.01.2016      2.80      3.02      2.80      3.96        3.50
# ...          ...       ...       ...       ...       ...         ...
# 1865  20.12.2021      2.22      3.49      2.67      4.00        5.89
# 1866  21.12.2021      2.00      3.47      2.50      5.00        6.36
# 1867  22.12.2021      2.00      3.67      2.50      5.00        6.21
# 1868  23.12.2021      2.50      3.31      2.50      5.00        5.92
# 1871  26.12.2021       NaN      3.62      2.45      5.30        6.25
#
#       Cucumber B  Green Apple A  Green Apple B  Green Cabbage A  ...  \
# 2           5.10           4.27            7.0             4.70  ...
# 3           4.40           4.77            7.5             5.00  ...
# 4           4.40           4.27            7.0             5.00  ...
# 5           4.00           5.30            6.8             4.40  ...
# 6           4.90           4.57            7.3             4.40  ...
# ...          ...            ...            ...              ...  ...
# 1865        5.75           5.27            8.0             1.45  ...
# 1866        6.22           5.27            8.0             1.44  ...
# 1867        6.07           5.27            8.0             1.34  ...
# 1868        5.78           5.27            8.0             1.27  ...
# 1871         NaN            NaN            8.0             1.32  ...
#
#       Red Cabbage A  Red Cabbage B  Red Pepper A  Red Pepper B  \
# 2              6.00           6.10          8.00          8.10
# 3              6.00           6.50          8.20          8.80
# 4              5.90           6.20          6.60          7.90
# 5              5.50           5.70          7.00          7.60
# 6              5.40           5.40          4.90          7.70
# ...             ...            ...           ...           ...
# 1865           2.10           4.71          3.17          5.68
# 1866           2.46           5.07          3.00          5.63
# 1867           2.50           5.11          3.00          5.86
# 1868           2.28           4.89          3.70          5.27
# 1871           2.23            NaN          3.50          5.25
#
#       Sweet-Potato A  Sweet-Potato B  Tomatoe A  Tomatoe B  Yellow Pepper A  \
# 2               2.70             NaN       9.10      10.10             6.40
# 3               2.00             NaN       8.19       9.90             6.90
# 4               2.40             NaN      10.00      10.20             7.30
# 5               2.10             NaN       8.00       8.40             7.00
# 6               2.60             NaN       7.70       8.00             6.00
# ...              ...             ...        ...        ...              ...
# 1865            3.00             5.0       3.00       4.50             3.00
# 1866            2.95             5.0       2.79       4.50             3.25
# 1867            3.00             5.0       3.00       4.50             3.00
# 1868            2.95             5.0       3.35       5.06             3.38
# 1871            2.93             5.0        NaN       4.77              NaN
#
#       Yellow Pepper B
# 2                7.50
# 3                7.30
# 4                7.50
# 5                7.10
# 6                6.90
# ...               ...
# 1865             5.75
# 1866             6.00
# 1867             6.06
# 1868             5.25
# 1871             5.09
#
# [1127 rows x 28 columns]

# %%
df_splitDate = p_df2.copy()

# %%
df_splitDate[['day','month','year']] = df_splitDate['Date'].str.split(".", expand = True)
df_splitDate
# Out:
#             Date  Banana A  Banana B  Carrot A  Carrot B  Cucumber A  \
# 2     03.01.2016      2.90      3.12      2.70      3.86        4.60
# 3     04.01.2016      2.90      3.12      2.70      3.86        4.10
# 4     05.01.2016      2.90      3.12      2.60      3.76        3.20
# 5     06.01.2016      2.80      3.02      2.90      4.06        3.50
# 6     07.01.2016      2.80      3.02      2.80      3.96        3.50
# ...          ...       ...       ...       ...       ...         ...
# 1865  20.12.2021      2.22      3.49      2.67      4.00        5.89
# 1866  21.12.2021      2.00      3.47      2.50      5.00        6.36
# 1867  22.12.2021      2.00      3.67      2.50      5.00        6.21
# 1868  23.12.2021      2.50      3.31      2.50      5.00        5.92
# 1871  26.12.2021       NaN      3.62      2.45      5.30        6.25
#
#       Cucumber B  Green Apple A  Green Apple B  Green Cabbage A  ...  \
# 2           5.10           4.27            7.0             4.70  ...
# 3           4.40           4.77            7.5             5.00  ...
# 4           4.40           4.27            7.0             5.00  ...
# 5           4.00           5.30            6.8             4.40  ...
# 6           4.90           4.57            7.3             4.40  ...
# ...          ...            ...            ...              ...  ...
# 1865        5.75           5.27            8.0             1.45  ...
# 1866        6.22           5.27            8.0             1.44  ...
# 1867        6.07           5.27            8.0             1.34  ...
# 1868        5.78           5.27            8.0             1.27  ...
# 1871         NaN            NaN            8.0             1.32  ...
#
#       Red Pepper B  Sweet-Potato A  Sweet-Potato B  Tomatoe A  Tomatoe B  \
# 2             8.10            2.70             NaN       9.10      10.10
# 3             8.80            2.00             NaN       8.19       9.90
# 4             7.90            2.40             NaN      10.00      10.20
# 5             7.60            2.10             NaN       8.00       8.40
# 6             7.70            2.60             NaN       7.70       8.00
# ...            ...             ...             ...        ...        ...
# 1865          5.68            3.00             5.0       3.00       4.50
# 1866          5.63            2.95             5.0       2.79       4.50
# 1867          5.86            3.00             5.0       3.00       4.50
# 1868          5.27            2.95             5.0       3.35       5.06
# 1871          5.25            2.93             5.0        NaN       4.77
#
#       Yellow Pepper A  Yellow Pepper B  day  month  year
# 2                6.40             7.50   03     01  2016
# 3                6.90             7.30   04     01  2016
# 4                7.30             7.50   05     01  2016
# 5                7.00             7.10   06     01  2016
# 6                6.00             6.90   07     01  2016
# ...               ...              ...  ...    ...   ...
# 1865             3.00             5.75   20     12  2021
# 1866             3.25             6.00   21     12  2021
# 1867             3.00             6.06   22     12  2021
# 1868             3.38             5.25   23     12  2021
# 1871              NaN             5.09   26     12  2021
#
# [1127 rows x 31 columns]

# %%
for i in range(1,10):
    df_splitDate['month']=df_splitDate['month'].str.replace("0"+str(i), str(i))
    df_splitDate['day']=df_splitDate['day'].str.replace("0"+str(i), str(i))
    
df_splitDate
# Out:
#             Date  Banana A  Banana B  Carrot A  Carrot B  Cucumber A  \
# 2     03.01.2016      2.90      3.12      2.70      3.86        4.60
# 3     04.01.2016      2.90      3.12      2.70      3.86        4.10
# 4     05.01.2016      2.90      3.12      2.60      3.76        3.20
# 5     06.01.2016      2.80      3.02      2.90      4.06        3.50
# 6     07.01.2016      2.80      3.02      2.80      3.96        3.50
# ...          ...       ...       ...       ...       ...         ...
# 1865  20.12.2021      2.22      3.49      2.67      4.00        5.89
# 1866  21.12.2021      2.00      3.47      2.50      5.00        6.36
# 1867  22.12.2021      2.00      3.67      2.50      5.00        6.21
# 1868  23.12.2021      2.50      3.31      2.50      5.00        5.92
# 1871  26.12.2021       NaN      3.62      2.45      5.30        6.25
#
#       Cucumber B  Green Apple A  Green Apple B  Green Cabbage A  ...  \
# 2           5.10           4.27            7.0             4.70  ...
# 3           4.40           4.77            7.5             5.00  ...
# 4           4.40           4.27            7.0             5.00  ...
# 5           4.00           5.30            6.8             4.40  ...
# 6           4.90           4.57            7.3             4.40  ...
# ...          ...            ...            ...              ...  ...
# 1865        5.75           5.27            8.0             1.45  ...
# 1866        6.22           5.27            8.0             1.44  ...
# 1867        6.07           5.27            8.0             1.34  ...
# 1868        5.78           5.27            8.0             1.27  ...
# 1871         NaN            NaN            8.0             1.32  ...
#
#       Red Pepper B  Sweet-Potato A  Sweet-Potato B  Tomatoe A  Tomatoe B  \
# 2             8.10            2.70             NaN       9.10      10.10
# 3             8.80            2.00             NaN       8.19       9.90
# 4             7.90            2.40             NaN      10.00      10.20
# 5             7.60            2.10             NaN       8.00       8.40
# 6             7.70            2.60             NaN       7.70       8.00
# ...            ...             ...             ...        ...        ...
# 1865          5.68            3.00             5.0       3.00       4.50
# 1866          5.63            2.95             5.0       2.79       4.50
# 1867          5.86            3.00             5.0       3.00       4.50
# 1868          5.27            2.95             5.0       3.35       5.06
# 1871          5.25            2.93             5.0        NaN       4.77
#
#       Yellow Pepper A  Yellow Pepper B  day  month  year
# 2                6.40             7.50    3      1  2016
# 3                6.90             7.30    4      1  2016
# 4                7.30             7.50    5      1  2016
# 5                7.00             7.10    6      1  2016
# 6                6.00             6.90    7      1  2016
# ...               ...              ...  ...    ...   ...
# 1865             3.00             5.75   20     12  2021
# 1866             3.25             6.00   21     12  2021
# 1867             3.00             6.06   22     12  2021
# 1868             3.38             5.25   23     12  2021
# 1871              NaN             5.09   26     12  2021
#
# [1127 rows x 31 columns]

# %%
df_splitDate['day'] = df_splitDate['day'].astype(int)
df_splitDate['month'] = df_splitDate['month'].astype(int)
df_splitDate['year'] = df_splitDate['year'].astype(int)

# %%
bp = df_splitDate.loc[df_splitDate['month'] == 5].loc[df_splitDate['year'] == 2020].mean()
#df.loc[df['column_name'] == some_value]
# Out:
# C:\Users\ED9E~1\AppData\Local\Temp/ipykernel_13632/2350400823.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bp = df_splitDate.loc[df_splitDate['month'] == 5].loc[df_splitDate['year'] == 2020].mean()

# %%
df_splitDate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1127 entries, 2 to 1871
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             1127 non-null   object
#  1   Banana A         971 non-null    float64
#  2   Banana B         1126 non-null   float64
#  3   Carrot A         1119 non-null   float64
#  4   Carrot B         1126 non-null   float64
#  5   Cucumber A       1127 non-null   float64
#  6   Cucumber B       1126 non-null   float64
#  7   Green Apple A    1125 non-null   float64
#  8   Green Apple B    1126 non-null   float64
#  9   Green Cabbage A  1127 non-null   float64
#  10  Green Cabbage B  1126 non-null   float64
#  11  Lemon A          1127 non-null   float64
#  12  Lemon B          1127 non-null   float64
#  13  Letture A        1098 non-null   float64
#  14  Pear A           1108 non-null   float64
#  15  Pear B           1103 non-null   float64
#  16  Red Apple A      1092 non-null   float64
#  17  Red Apple B      1092 non-null   float64
#  18  Red Cabbage A    1127 non-null   float64
#  19  Red Cabbage B    1126 non-null   float64
#  20  Red Pepper A     1127 non-null   float64
#  21  Red Pepper B     1127 non-null   float64
#  22  Sweet-Potato A   1101 non-null   float64
#  23  Sweet-Potato B   1051 non-null   float64
#  24  Tomatoe A        1125 non-null   float64
#  25  Tomatoe B        1126 non-null   float64
#  26  Yellow Pepper A  1126 non-null   float64
#  27  Yellow Pepper B  1127 non-null   float64
#  28  day              1127 non-null   int32
#  29  month            1127 non-null   int32
#  30  year             1127 non-null   int32
# dtypes: float64(27), int32(3), object(1)
# memory usage: 300.8+ KB

# %%
bpp = pd.DataFrame()
for i in range(2016,2022):
    for j in range(1,13):
        bp = df_splitDate.loc[df_splitDate['month'] == j].loc[df_splitDate['year'] == i].mean()
        bpp = bpp.append(bp, ignore_index = True)
bpp= bpp.drop("day", axis=1)
bpp
# Out:
# C:\Users\ED9E~1\AppData\Local\Temp/ipykernel_13632/4090193281.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bp = df_splitDate.loc[df_splitDate['month'] == j].loc[df_splitDate['year'] == i].mean()
#     Banana A  Banana B  Carrot A  Carrot B  Cucumber A  Cucumber B  \
# 0   3.861111  4.081111  2.611111  3.771111    3.861111    4.135556
# 1   5.146154  5.366154  2.346154  3.506154    4.353846    4.213846
# 2   5.766667  5.986667  2.075000  3.235000    3.933333    3.793333
# 3   6.292857  6.512857  1.992857  3.152857    2.807143    2.667143
# 4   6.407692  6.627692  1.969231  3.129231    4.153846    4.013846
# ..       ...       ...       ...       ...         ...         ...
# 67  3.416500  5.501500  3.169500  3.756000    4.393500    4.253500
# 68  3.010909  4.595455  3.404545  4.298182    4.192727    4.052727
# 69  2.826667  4.386111  3.122222  3.544444    3.217778    3.077778
# 70  2.421053  3.226316  2.910000  3.490000    4.700526    4.560526
# 71  2.095882  2.896111  2.517778  3.841667    5.433889    5.245882
#
#     Green Apple A  Green Apple B  Green Cabbage A  Green Cabbage B  ...  \
# 0        4.798235       6.982353         3.594444         4.846111  ...
# 1        4.029231       6.407692         2.130769         4.400769  ...
# 2        4.015000       6.366667         1.366667         3.636667  ...
# 3        4.087143       6.792857         0.992857         3.262857  ...
# 4        4.242308       7.176923         1.323077         3.593077  ...
# ..            ...            ...              ...              ...  ...
# 67       5.770000       8.500000         2.761000         5.031000  ...
# 68       5.774545       8.504545         4.980909         7.250909  ...
# 69       5.770000       8.500000         2.294444         4.564444  ...
# 70       5.732632       8.462632         1.841053         4.111053  ...
# 71       5.404706       8.127222         1.334444         3.605294  ...
#
#     Red Pepper A  Red Pepper B  Sweet-Potato A  Sweet-Potato B  Tomatoe A  \
# 0       5.788889      7.294444        2.533333             NaN   5.798333
# 1       5.876923      8.023077        2.607692             NaN   2.842308
# 2       5.700000      7.600000        2.485455        2.700000   1.653333
# 3       4.328571      7.057143        2.057143        2.978571   3.182857
# 4       6.315385      9.707692        2.253846        3.046154   2.460769
# ..           ...           ...             ...             ...        ...
# 67      3.320000      5.910500        3.054706        5.000000   3.051000
# 68      4.432727      8.150909        2.763636        5.094444   3.706364
# 69      4.371667      6.557222        3.423889        5.051667   3.651667
# 70      3.328421      5.550000        3.283158        5.026667   3.035789
# 71      3.167778      5.001667        2.933333        5.000000   2.971176
#
#     Tomatoe B  Yellow Pepper A  Yellow Pepper B  month    year
# 0    6.483333         5.683333         6.972222    1.0  2016.0
# 1    3.838462         5.213077         7.976923    2.0  2016.0
# 2    2.850000         5.030833         7.891667    3.0  2016.0
# 3    4.864286         4.085714         6.978571    4.0  2016.0
# 4    3.484615         5.653846         8.723077    5.0  2016.0
# ..        ...              ...              ...    ...     ...
# 67   5.156500         3.397500         6.231000    8.0  2021.0
# 68   6.062727         4.585455         8.521818    9.0  2021.0
# 69   5.396667         4.524444         7.127222   10.0  2021.0
# 70   4.697895         3.573158         5.626842   11.0  2021.0
# 71   4.511667         3.084118         5.043333   12.0  2021.0
#
# [72 rows x 29 columns]

# %%
data_rains = pd.read_csv ('Rains_Dataframe.csv')

# %%
data_rains
# Out:
#                                                stn_name  rain_code  \
# 0     REGAVIM                                       ...          0
# 1     KEFAR HAROE                                   ...          0
# 2     ENAT                                          ...          0
# 3     NES ZIYYONA                                   ...          0
# 4     NIZZAN                                        ...          0
# ...                                                 ...        ...
# 1321  PARAN                                         ...          0
# 1322  YOTVATA                                       ...          0
# 1323  YONATAN                                       ...          0
# 1324  AVNE ETAN                                     ...          0
# 1325  MEROM GOLAN PICMAN                            ...          0
#
#       rain_days_num  rain_max_code  rain_max_val  rain_ttl  year  month
# 0                14              0          64.1     166.3  2016      1
# 1                13              5          21.0      96.8  2016      1
# 2                12              5          21.3     114.6  2016      1
# 3                10              5          16.5      96.0  2016      1
# 4                11              0          18.8      73.1  2016      1
# ...             ...            ...           ...       ...   ...    ...
# 1321              1              0           0.2       0.2  2021     10
# 1322              1              0           0.3       0.3  2021     10
# 1323              4              0           2.7       5.1  2021     10
# 1324              4              0           2.6       4.6  2021     10
# 1325              7              0           6.2       9.2  2021     10
#
# [1326 rows x 8 columns]

# %%
#rp = data_rains.loc[data_rains['month'] == j].loc[data_rains['year'] == i].mean()
# Out:
# C:\Users\ED9E~1\AppData\Local\Temp/ipykernel_13632/1607956280.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   rp = data_rains.loc[data_rains['month'] == j].loc[data_rains['year'] == i].mean()

# %%
rpp = pd.DataFrame()
for i in range(2016,2022):
    for j in range(1,13):
        rp = data_rains.loc[data_rains['month'] == j].loc[data_rains['year'] == i].mean()
        rpp = rpp.append(rp, ignore_index = True)
rpp
# Out:
# C:\Users\ED9E~1\AppData\Local\Temp/ipykernel_13632/798813642.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   rp = data_rains.loc[data_rains['month'] == j].loc[data_rains['year'] == i].mean()
#     rain_code  rain_days_num  rain_max_code  rain_max_val    rain_ttl    year  \
# 0    0.000000      10.142857       0.714286     30.652381  108.157143  2016.0
# 1    0.000000       5.428571       0.476190     33.480952   71.504762  2016.0
# 2    0.761905       7.571429       1.285714     14.571429   32.585714  2016.0
# 3    0.333333       2.904762       1.523810     16.280952   21.333333  2016.0
# 4    1.428571       1.619048       1.476190      1.357143    2.457143  2016.0
# ..        ...            ...            ...           ...         ...     ...
# 67   0.000000       0.000000       0.000000      0.000000    0.000000  2021.0
# 68   1.105263       0.894737       1.368421      1.000000    1.184211  2021.0
# 69   0.736842       2.684211       1.000000      1.973684    2.800000  2021.0
# 70        NaN            NaN            NaN           NaN         NaN     NaN
# 71        NaN            NaN            NaN           NaN         NaN     NaN
#
#     month  stn_name
# 0     1.0       NaN
# 1     2.0       NaN
# 2     3.0       NaN
# 3     4.0       NaN
# 4     5.0       NaN
# ..    ...       ...
# 67    8.0       NaN
# 68    9.0       NaN
# 69   10.0       NaN
# 70    NaN       NaN
# 71    NaN       NaN
#
# [72 rows x 8 columns]

# %%
rpp = rpp.drop("stn_name", axis=1)

# %%
rpp
# Out:
#     rain_code  rain_days_num  rain_max_code  rain_max_val    rain_ttl    year  \
# 0    0.000000      10.142857       0.714286     30.652381  108.157143  2016.0
# 1    0.000000       5.428571       0.476190     33.480952   71.504762  2016.0
# 2    0.761905       7.571429       1.285714     14.571429   32.585714  2016.0
# 3    0.333333       2.904762       1.523810     16.280952   21.333333  2016.0
# 4    1.428571       1.619048       1.476190      1.357143    2.457143  2016.0
# ..        ...            ...            ...           ...         ...     ...
# 67   0.000000       0.000000       0.000000      0.000000    0.000000  2021.0
# 68   1.105263       0.894737       1.368421      1.000000    1.184211  2021.0
# 69   0.736842       2.684211       1.000000      1.973684    2.800000  2021.0
# 70        NaN            NaN            NaN           NaN         NaN     NaN
# 71        NaN            NaN            NaN           NaN         NaN     NaN
#
#     month
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# ..    ...
# 67    8.0
# 68    9.0
# 69   10.0
# 70    NaN
# 71    NaN
#
# [72 rows x 7 columns]

# %%
rains_vegs = bpp.copy()
rains_vegs['rain_days_num'] = rpp['rain_days_num']
rains_vegs['rain_max_code'] = rpp['rain_max_code']
rains_vegs['max_val'] = rpp['rain_max_val']
rains_vegs['rain_ttl'] = rpp['rain_ttl']
rains_vegs
# Out:
#     Banana A  Banana B  Carrot A  Carrot B  Cucumber A  Cucumber B  \
# 0   3.861111  4.081111  2.611111  3.771111    3.861111    4.135556
# 1   5.146154  5.366154  2.346154  3.506154    4.353846    4.213846
# 2   5.766667  5.986667  2.075000  3.235000    3.933333    3.793333
# 3   6.292857  6.512857  1.992857  3.152857    2.807143    2.667143
# 4   6.407692  6.627692  1.969231  3.129231    4.153846    4.013846
# ..       ...       ...       ...       ...         ...         ...
# 67  3.416500  5.501500  3.169500  3.756000    4.393500    4.253500
# 68  3.010909  4.595455  3.404545  4.298182    4.192727    4.052727
# 69  2.826667  4.386111  3.122222  3.544444    3.217778    3.077778
# 70  2.421053  3.226316  2.910000  3.490000    4.700526    4.560526
# 71  2.095882  2.896111  2.517778  3.841667    5.433889    5.245882
#
#     Green Apple A  Green Apple B  Green Cabbage A  Green Cabbage B  ...  \
# 0        4.798235       6.982353         3.594444         4.846111  ...
# 1        4.029231       6.407692         2.130769         4.400769  ...
# 2        4.015000       6.366667         1.366667         3.636667  ...
# 3        4.087143       6.792857         0.992857         3.262857  ...
# 4        4.242308       7.176923         1.323077         3.593077  ...
# ..            ...            ...              ...              ...  ...
# 67       5.770000       8.500000         2.761000         5.031000  ...
# 68       5.774545       8.504545         4.980909         7.250909  ...
# 69       5.770000       8.500000         2.294444         4.564444  ...
# 70       5.732632       8.462632         1.841053         4.111053  ...
# 71       5.404706       8.127222         1.334444         3.605294  ...
#
#     Tomatoe A  Tomatoe B  Yellow Pepper A  Yellow Pepper B  month    year  \
# 0    5.798333   6.483333         5.683333         6.972222    1.0  2016.0
# 1    2.842308   3.838462         5.213077         7.976923    2.0  2016.0
# 2    1.653333   2.850000         5.030833         7.891667    3.0  2016.0
# 3    3.182857   4.864286         4.085714         6.978571    4.0  2016.0
# 4    2.460769   3.484615         5.653846         8.723077    5.0  2016.0
# ..        ...        ...              ...              ...    ...     ...
# 67   3.051000   5.156500         3.397500         6.231000    8.0  2021.0
# 68   3.706364   6.062727         4.585455         8.521818    9.0  2021.0
# 69   3.651667   5.396667         4.524444         7.127222   10.0  2021.0
# 70   3.035789   4.697895         3.573158         5.626842   11.0  2021.0
# 71   2.971176   4.511667         3.084118         5.043333   12.0  2021.0
#
#     rain_days_num  rain_max_code    max_val    rain_ttl
# 0       10.142857       0.714286  30.652381  108.157143
# 1        5.428571       0.476190  33.480952   71.504762
# 2        7.571429       1.285714  14.571429   32.585714
# 3        2.904762       1.523810  16.280952   21.333333
# 4        1.619048       1.476190   1.357143    2.457143
# ..            ...            ...        ...         ...
# 67       0.000000       0.000000   0.000000    0.000000
# 68       0.894737       1.368421   1.000000    1.184211
# 69       2.684211       1.000000   1.973684    2.800000
# 70            NaN            NaN        NaN         NaN
# 71            NaN            NaN        NaN         NaN
#
# [72 rows x 33 columns]
